# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely import wkt

# %%
train = pd.read_csv("../resources/Train.csv")
test = pd.read_csv("../resources/Test.csv")

# %%
# Convert WKT geometry to actual geometry objects in both datasets
train['geometry'] = train['geometry'].apply(wkt.loads)
test['geometry'] = test['geometry'].apply(wkt.loads)

# %%
# Convert pandas DataFrames to GeoDataFrames with CRS set to 'epsg:4326'
train = gpd.GeoDataFrame(train, crs='epsg:4326')
test = gpd.GeoDataFrame(test, crs='epsg:4326')

# %%
train.category.value_counts()

# %%
train.info()

# %%
train.shape

# %%
train['Crop'].value_counts()

# %%
train['IrriType'].value_counts()

# %%
train['CTransp'].value_counts()

# %%
train['IrriSource'].value_counts()

# %%
target = ['Healthy', 'Diseased','Pests', 'Stressed']
numerical_cols = ['CropCoveredArea', 'CHeight', 'IrriCount', 'WaterCov', 'ExpYield']
categorical_cols = crop_info.columns.difference(numerical_cols).to_list()

# %%
train['Season'].value_counts()

# %%
train['District'].value_counts()

# %%
train['CLast'].value_counts()

# %%
train['CNext'].value_counts()

# %%
cols2 = ['category','CropCoveredArea', 'CHeight', 'IrriCount', 'WaterCov', 'ExpYield']

# %%
train['SDate'] = pd.to_datetime(train['SDate']) 
train['HDate'] = pd.to_datetime(train['HDate'])

# %%
# Find the range
min_date =train['SDate'].min()
max_date = train['SDate'].max()

date_range = max_date - min_date

print("Earliest date:", min_date)
print("Latest date:", max_date)
print("Date range:", date_range)

# %%
min_date2 =train['HDate'].min()
max_date2 = train['HDate'].max()

date_range2 = max_date2 - min_date2

print("Earliest date:", min_date2)
print("Latest date:", max_date2)
print("Date range:", date_range2)

# %%
train = train.to_crs(epsg=32644)

# %%
train['area'] = train.geometry.area

# %%
min_area =train['area'].min()
max_area = train['area'].max()

mean_area = np.mean(train['area'])

# %%
mean_area
